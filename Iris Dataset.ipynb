# %%
import pandas as pd
import numpy as np
# %matplotlib inline
# Out:
# C:\Users\91887\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\91887\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
from sklearn.datasets import load_iris
iris_dataset=load_iris()
# Out:
# C:\Users\91887\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\91887\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
print("Keys of iris datasets:\n{}".format(iris_dataset.keys()))
# Out:
# Keys of iris datasets:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(iris_dataset['data'],iris_dataset['target'],random_state=0)

# %%
print('X_train:{}'.format(X_train.shape))
print('y_train:{}'.format(y_train.shape))
# Out:
# X_train:(112, 4)
# y_train:(112,)

# %%
print('X_test shape:{}'.format(X_test.shape))
print('y_test shape:{}'.format(y_test.shape))
# Out:
# X_test shape:(38, 4)
# y_test shape:(38,)

# %%
df=pd.DataFrame(X_train,columns=iris_dataset['feature_names'])

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.9               3.0                4.2               1.5
# 1                5.8               2.6                4.0               1.2
# 2                6.8               3.0                5.5               2.1
# 3                4.7               3.2                1.3               0.2
# 4                6.9               3.1                5.1               2.3

# %%
pd.plotting.scatter_matrix(df,figsize=(12,10),alpha=1,diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA18A788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA433948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA1AEF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA1E79C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA2233C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA257D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CF47F39C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA415848>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA415048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CF727DF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CF42ECEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CF4804F48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA30F5C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA348708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA37E808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022CFA3B7908>]],
#       dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
predict=knn.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,predict)
# Out:
# 0.9536585365853658
